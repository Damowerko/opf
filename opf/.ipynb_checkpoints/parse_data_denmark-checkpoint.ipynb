# %%
import pandas as pd
import pandapower as pp
import re
import numpy as np
import os

def fix_decimals(value):
    # replace things like 10,00 with 10.00 - European to US decimals
    if isinstance(value, str) and re.search("[0-9]+,[0-9]+", value):
        return float(value.replace(',', '.'))
    return value

root_dir = "C:/Users/Damian/OneDrive/Share/Penn/Research/OPF/"
input_dir = root_dir + "data/denmark/"
output_dir = root_dir + "data/output/"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

bus_data = pd.read_excel(input_dir + "raw.xlsx", skiprows=range(0, 3), sheet_name='Bus').sort_values('Bus Index').applymap(
    fix_decimals)
line_data = pd.read_excel(input_dir + "raw.xlsx", skiprows=range(0, 3), sheet_name='Line').applymap(fix_decimals)
trafo2_data = pd.read_excel(input_dir + "raw.xlsx", skiprows=range(0, 3), sheet_name='Transformer2').applymap(fix_decimals)
trafo3_data = pd.read_excel(input_dir + "raw.xlsx", skiprows=range(0, 3), sheet_name='Transformer3').applymap(fix_decimals)
generator_data = pd.read_excel(input_dir + "raw.xlsx", skiprows=range(0, 3), sheet_name='Generator').applymap(fix_decimals)
load_data = pd.read_excel(input_dir + "raw.xlsx", skiprows=range(0, 3), sheet_name='Load').applymap(fix_decimals)
shunt_data = pd.read_excel(input_dir + "raw.xlsx", skiprows=range(0, 3), sheet_name='Shunt').applymap(fix_decimals)
hvdc_data = pd.read_excel(input_dir + "raw.xlsx", skiprows=range(0, 3), sheet_name='HVDC').applymap(fix_decimals)

# %%
net = pp.create_empty_network("Denmark")

for _, row in bus_data.iterrows():
    row: pd.Series = row
    voltage = row['Voltage base[kV]']
    pp.create_bus(net, voltage, name=row['Bus Name'], index=row['Bus Index'], max_vm_pu=row['Voltage min[pu]'],
                  min_vm_pu=row['Voltage max[pu]'])
    if row['Fictitious Border Node']:
        pp.create_ext_grid(net, row['Bus Name'])

for _, row in line_data.iterrows():
    row: pd.Series = row

    type = row['Line type']
    L: float = row['Length[km]']
    R: float = row['R1[Ohm]']
    X: float = row['X1[Ohm]']
    G: float = row['G1[uS]']
    B: float = row['B1[uS]']
    limit_current = row['Nominal Current[kA]'] * 1.1  # TODO: Verify
    C = 10  # TODO: verify
    if type == "Null Line" or (R < 0.01 or X < 0.01):
        pp.create_switch(net, row['Node 1'], row['Node 2'], 'b', True, z_ohm=row['R1[Ohm]'])
    elif type == "Overhead Line" or type == "Cable":
        pp.create_line_from_parameters(net, row['Node 1'], row['Node 2'], L, R/L, X/L, C, limit_current, 
                                       g_us_per_km=G/L)
    
    elif type == "Equivalent Impedance":
        sn_mva: float = row['Nominal Current[kA]'] * row['Nominal Voltage[kV]']
        pu_factor: float = net.sn_mva / sn_mva
        pp.create_impedance(net, row['Node 1'], row['Node 2'], R/pu_factor, X/pu_factor, sn_mva, R/pu_factor,
                            X/pu_factor, in_service=True)
    else:
        raise RuntimeError("{} is an unknown line type".format(type))
        
# Based on https://www.fs.fed.us/database/acad/elec/greenbook/10_shortcalc.pdf
# X/R is ~3.5 therefore %R is %Z/(1+3.5)
Z_XR_factor = 1/(1+3.5)
for _, row in trafo2_data.iterrows():
    row: pd.Series = row
    # Assuming core losses are approximately equal to no load loss
    # Assuming short circuit voltage is purely real
    # Assuming max loading percent is 100
    pp.create_transformer_from_parameters(net, row['High.V Bus Index'], row['Low.V Bus Index'], row['Sn[MVA]'],
                                          row['Un.H[kV]'], row['Un.L[kV]'], row['uk[%]']*Z_XR_factor, row['uk[%]'], 
                                          row['No Load Losses[kW]'], row['No Load Current[%]'], in_service=True,
                                          tap_min=row['Min.Tap'], tap_max=row['Max.Tap'], tap_neutral=row['Neu.Tap'],
                                          shift_degree=row['dUphase[deg]'], tap_step_percent=row['dU.Tap[%]'],
                                          tap_side="hv", tap_pos=row['Act.Tap'], max_loading_percent=100)

for _, row in trafo3_data.iterrows():
    row: pd.Series = row
    # Same assumptions as trafo2, AND
    # Assuming phase shift is the same for LV and MV
    control_bus = row['Control Bus Index']
    hBusIndex = row['High.V Bus Index']
    mBusIndex = row['Mid.V Bus Index']
    lBusIndex = row['Low.V Bus Index']
    tap_side = row['Tap Side'].lower()
    shift_degree = row['dUphase.Tap[deg]']

    # Same as trafo2
    pp.create_transformer3w_from_parameters(net, hBusIndex, mBusIndex, hBusIndex,
                                            row['Un.H[kV]'], row['Un.M[kV]'], row['Un.L[kV]'],
                                            row['Sn[MVA]'], row['Sn[MVA]'], row['Sn[MVA]'],
                                            row['uk.HV_MV[%]'], row['uk.MV_LV[%]'], row['uk.LV_HV[%]'],
                                            row['uk.HV_MV[%]']*Z_XR_factor,
                                            row['uk.MV_LV[%]']*Z_XR_factor, 
                                            row['uk.LV_HV[%]']*Z_XR_factor,
                                            row['No Load Losses[kW]'], row['No Load Current[%]'], tap_side=tap_side,
                                            tap_min=row['Min.Tap'], tap_max=row['Max.Tap'], tap_neutral=row['Neu.Tap'],
                                            tap_step_percent=row['dU.Tap[%]'], tap_pos=row['Act.Tap'],
                                            in_service=True, shift_lv_degree=shift_degree, shift_mv_degree=shift_degree)

for _, row in generator_data.iterrows():
    row: pd.Series = row

    control_type = row['Control Type']
    slack = control_type == "SL"  # this is a slack generator
    p_mw = row['Act.P[MW]']
    q_mvar = row['Act.Q[Mvar]']
    if control_type == "PQ":
        pp.create_sgen(net, row['Bus Index'], p_mw, q_mvar,
                       row['Nominal Apparent Power[MVA]'], row['Generator Name'],
                       max_p_mw=row['Pmax[MW]'], min_p_mw=row['Pmin[MW]'],
                       max_q_mvar=row['Qmax[Mvar]'], min_q_mvar=row['Qmin[Mvar]'],
                       controllable=True)
    elif control_type == "PV" or slack:

        # Approximating these plants which compensate for voltage variance of renewable plants by
        # placing them on the Control bus
        pp.create_gen(net, row['Control Bus Index'], p_mw, row['Uref[pu]'],
                      row['Nominal Apparent Power[MVA]'], row['Generator Name'],
                      max_p_mw=row['Pmax[MW]'], min_p_mw=row['Pmin[MW]'],
                      max_q_mvar=row['Qmax[Mvar]'], min_q_mvar=row['Qmin[Mvar]'],
                      controllable=True, slack=slack)
    else:
        raise Exception("{} control type is not defined.".format(control_type))

for _, row in load_data.iterrows():
    row: pd.Series = row

    p_mw: float = row['Act.P[MW]']
    q_mvar: float = row['Act.Q[Mvar]']
    # ZIP model data: https://www.diva-portal.org/smash/get/diva2:1085518/FULLTEXT01.pdf page 61 (83 on pdf)
    # [Z I P]
    p: np.ndarray = np.array([0.38, 0.41, 0.21])
    q: np.ndarray = np.array([1, 0, 0])
    aggregate = (p * p_mw + q * q_mvar)

    if np.sum(aggregate) == 0:
        aggregate = np.array([100, 0, 0])
    else:
        aggregate = 100 * aggregate / np.sum(aggregate)  # values should be in [0,100]
    
    if p_mw >= 0:
        pp.create_load(net, row['Load Index'], p_mw, q_mvar, aggregate[0], aggregate[1], controllable=False)
    else:
        pp.create_sgen(net, row['Load Index'], -p_mw, q_mvar, p_mw)

for _, row in shunt_data.iterrows():
    row: pd.Series = row
    switchable = row['Switchable']
    step = row['Act.Step']
    pp.create_shunt(net, row['Bus Index'], row['L[Mvar]'] + row['C[Mvar]'], vn_kv=row['Nominal Voltage[kV]'],
                    step=step, max_step=row['Max.Step'], name=row['Shunt Name'])

for _, row in hvdc_data.iterrows():
    row: pd.Series = row
    pp.create_load(net, row['Bus Index'], -row['Act.P[MW]'], -row['Act.Q[Mvar]'], controllable=True,
                   max_p_mw=row['Pmax[MW]'], max_q_mvar=row['Q[Mvar]'], min_p_mw=0, min_q_mvar=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\damian\.virtualenvs\opf\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4380             try:
# -> 4381                 return libindex.get_value_box(s, key)
#    4382             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-876e8bb99cf5> in <module>
#       6     pp.create_bus(net, voltage, name=row['Bus Name'], index=row['Bus Index'], max_vm_pu=row['Voltage min[pu]'],
#       7                   min_vm_pu=row['Voltage max[pu]'])
# ----> 8     if row['Fictitious Border Node']:
#       9         pp.create_ext_grid(net, row['Bus Name'])
#      10
#
# c:\users\damian\.virtualenvs\opf\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# c:\users\damian\.virtualenvs\opf\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4387                     raise InvalidIndexError(key)
#    4388                 else:
# -> 4389                     raise e1
#    4390             except Exception:  # pragma: no cover
#    4391                 raise e1
#
# c:\users\damian\.virtualenvs\opf\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fictitious Border Node'

# %%
from pandapower import topology
import networkx as nx
from pandapower.plotting import simple_plot, to_html
from pandapower.plotting.plotly import simple_plotly, vlevel_plotly
from matplotlib import pyplot as plt

nx_graph = pp.topology.create_nxgraph(net)
CCs = sorted(list(nx.connected_components(nx_graph)), key=len, reverse=True)

net_train = pp.select_subnet(net, list(CCs[0]))
net_test = pp.select_subnet(net, list(CCs[1]))

pp.to_json(net_train, output_dir + "denmark_train.json")
pp.to_json(net_test, output_dir + "denmark_test.json")
pp.plotting.to_html(net_train, output_dir + "denmark_train.html")
pp.plotting.to_html(net_test, output_dir + "denmark_test.html")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-8e67f48638e9> in <module>
#       9
#      10 net_train = pp.select_subnet(net, list(CCs[0]))
# ---> 11 net_test = pp.select_subnet(net, list(CCs[1]))
#      12
#      13 pp.to_json(net_train, output_dir + "denmark_train.json")
#
# IndexError: list index out of range

# %%
results = pp.runpp(net_test, max_iteration=10)
# Out:
# ---------------------------------------------------------------------------
# LoadflowNotConverged                      Traceback (most recent call last)
# <ipython-input-11-395eae244e3a> in <module>
# ----> 1 results = pp.runpp(net_test, max_iteration=10)
#
# c:\users\damian\.virtualenvs\opf\lib\site-packages\pandapower\run.py in runpp(net, algorithm, calculate_voltage_angles, init, max_iteration, tolerance_mva, trafo_model, trafo_loading, enforce_q_lims, check_connectivity, voltage_depend_loads, consider_line_temperature, **kwargs)
#     210     _check_bus_index_and_print_warning_if_high(net)
#     211     _check_gen_index_and_print_warning_if_high(net)
# --> 212     _powerflow(net, **kwargs)
#     213
#     214
#
# c:\users\damian\.virtualenvs\opf\lib\site-packages\pandapower\powerflow.py in _powerflow(net, **kwargs)
#      80         _clean_up(net, res=False)
#      81         raise LoadflowNotConverged("Power Flow {0} did not converge after "
# ---> 82                                    "{1} iterations!".format(algorithm, max_iteration))
#      83     else:
#      84         net["_ppc"] = result
#
# LoadflowNotConverged: Power Flow nr did not converge after 10 iterations!

# %%
pp.diagnostic(net, 'compact', warnings_only=True)
# Out:
# c:\users\damian\.virtualenvs\opf\lib\site-packages\pandapower\auxiliary.py:689: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
#
#
# _____________ PANDAPOWER DIAGNOSTIC TOOL _____________
#
# disconnected_elements:
#
# disonnected_section: {'buses': [0]}
#
#  --------
#
# wrong_switch_configuration:
#
# Power flow still does not converge with all switches closed.
#
#  --------
#
# no_external_grid:
#
# No ext_grid found. There has to be at least one ext_grid!
#
#  --------
#
# _____________ END OF PANDAPOWER DIAGNOSTIC _____________
# {'disconnected_elements': [{'buses': [0]}],
#  'wrong_switch_configuration': False,
#  'no_ext_grid': True}

# %%
simple_plot(net_train)
plt.savefig(output_dir + "denmark_train.png")
simple_plot(net_test)
plt.savefig(output_dir + "denmark_test.png")
# Out:
# No or insufficient geodata available --> Creating artificial coordinates. This may take some time
# None in collections is of unknown type. Skipping
